# %%
import pandas as pd

# %%
df = pd.read_csv("final_dataset.csv", index_col=0)

# %%
df
# Out:
#        Subject number Expression  Eye_Left_Blink  Eye_Left_Wide  \
# 0                   0    Neutral        0.005194       0.011354
# 1                   0    Neutral        0.005948       0.000000
# 2                   0    Neutral        0.005907       0.000000
# 3                   0    Neutral        0.005153       0.000000
# 4                   0    Neutral        0.005153       0.000000
# ...               ...        ...             ...            ...
# 11053              52   Surprise        0.000000       0.174705
# 11054              52   Surprise        0.000000       0.174705
# 11055              52   Surprise        0.000000       0.219943
# 11056              52   Surprise        0.000000       0.219943
# 11057              52   Surprise        0.000000       0.251732
#
#        Eye_Left_Right  Eye_Left_Left  Eye_Left_Up  Eye_Left_Down  \
# 0                 0.0       0.120789     0.011354       0.136379
# ...
